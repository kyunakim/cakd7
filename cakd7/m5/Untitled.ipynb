# %% [markdown]
# ![%EC%BA%A1%EC%B2%98.PNG](attachment:%EC%BA%A1%EC%B2%98.PNG)

# %%
pip install cx_Oracle
# Out:
# ...
#
# [notice] A new release of pip available: 22.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import cx_Oracle 

# DB연동
conn = cx_Oracle.connect('c##cakd7/cakd7@localhost:1521/xe')
# conn = cx_Oracle.connect('접속이름/비밀번호@호스트이름:포트번호/SID)

# %%
cur = conn.cursor()
cur.execute("select * from competitor") #sql 쿼리 작성

for c in cur:
    print(c)
    
cur.close()
conn.close()
# Out:
# ('04112', 'D', 'D02', 201505)
# ('04112', 'D', 'D02', 201507)
# ('04112', 'D', 'D02', 201511)
# ('04112', 'D', 'D02', 201512)
# ('04115', 'D', 'D02', 201511)
# ('04121', 'D', 'D02', 201510)
# ('04126', 'D', 'D02', 201504)
# ('04131', 'D', 'D02', 201503)
# ('04138', 'D', 'D02', 201501)
# ('04138', 'D', 'D02', 201503)
# ('04138', 'D', 'D02', 201506)
# ('04138', 'D', 'D02', 201508)
# ('04138', 'D', 'D02', 201510)
# ('04138', 'D', 'D02', 201512)
# ('04143', 'D', 'D01', 201503)
# ('04143', 'D', 'D01', 201509)
# ('04143', 'D', 'D02', 201501)
# ('04143', 'D', 'D02', 201506)
# ('04153', 'D', 'D01', 201505)
# ('04153', 'D', 'D01', 201512)
# ('04153', 'D', 'D02', 201505)
# ('04153', 'D', 'D02', 201509)
# ('04162', 'D', 'D02', 201502)
# ('04162', 'D', 'D02', 201505)
# ('04172', 'D', 'D02', 201510)
# ('04178', 'D', 'D01', 201508)
# ('04182', 'D', 'D01', 201501)
# ('04185', 'D', 'D02', 201501)
# ('04219', 'D', 'D01', 201510)
# ('04257', 'D', 'D02', 201501)
# ('04257', 'D', 'D02', 201504)
# ...

# %%
import cx_Oracle 

# DB연동
conn = cx_Oracle.connect('c##cakd7/cakd7@localhost:1521/xe')
# conn = cx_Oracle.connect('접속이름/비밀번호@호스트이름:포트번호/SID)

# %%
# 커서
cur = conn.cursor()

import pandas as pd
query = "select * from competitor"
df = pd.read_sql_query(query,conn)
df
# Out:
#       CUSTNO ASSO COMPETITOR  PURDATE
# 0      04112    D        D02   201505
# 1      04112    D        D02   201507
# 2      04112    D        D02   201511
# 3      04112    D        D02   201512
# 4      04115    D        D02   201511
# ...      ...  ...        ...      ...
# 28154  19375    B        B01   201501
# 28155  19375    B        B01   201507
# 28156  19375    C        C03   201511
# 28157  19376    B        B01   201506
# 28158  19377    B        B01   201504
#
# [28159 rows x 4 columns]

# %%
# 커서
cur = conn.cursor()

import pandas as pd
query = "select * from demo"
df1 = pd.read_sql_query(query,conn)
df1
# Out:
# C:\Users\admin\anaconda3\envs\cakd7\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#       CUSTNO GENDER      AGE AREA
# 0      00501      F    60세이상  460
# 1      00502      F    60세이상  060
# 2      00503      F    60세이상  055
# 3      00504      F    60세이상  049
# 4      00505      F    60세이상  055
# ...      ...    ...      ...  ...
# 19378  18756      F  45세~49세  060
# 19379  18757      F  35세~39세  100
# 19380  18758      F    19세이하  210
# 19381  18759      M  35세~39세  100
# 19382  18760      F  25세~29세  082
#
# [19383 rows x 4 columns]

# %%
# 커서
cur = conn.cursor()

import pandas as pd
query = "select * from channel"
df2 = pd.read_sql_query(query,conn)
df2
# Out:
# C:\Users\admin\anaconda3\envs\cakd7\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#      CUSTNO          ASSO  FREQ
# 0     01477  B_MOBILE/APP    13
# 1     01480  B_MOBILE/APP    25
# 2     01493  B_MOBILE/APP    20
# 3     01498  A_MOBILE/APP     2
# 4     01507  B_MOBILE/APP     8
# ...     ...           ...   ...
# 8819  09379  B_ONLINEMALL     1
# 8820  09385  B_ONLINEMALL     3
# 8821  09388  B_ONLINEMALL    12
# 8822  09400  B_ONLINEMALL     1
# 8823  09405  B_ONLINEMALL    32
#
# [8824 rows x 3 columns]

# %%
# 커서
cur = conn.cursor()

import pandas as pd
query = "select * from member"
df3 = pd.read_sql_query(query,conn)
df3
# Out:
# C:\Users\admin\anaconda3\envs\cakd7\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#      CUSTNO MNAME  JOINMONTH
# 0     02182  하이마트     201404
# 1     02185  하이마트     201310
# 2     02186  하이마트     201306
# 3     02187  하이마트     201309
# 4     02190   다둥이     201303
# ...     ...   ...        ...
# 7451  19377    롭스     201411
# 7452  19379    롭스     201412
# 7453  19380    롭스     201412
# 7454  19381   다둥이     201506
# 7455  19383    롭스     201507
#
# [7456 rows x 3 columns]

# %%
# customer

# %%
# custno 로 데이터프레임 합치기 (df,df1,df2,df3)

# %%
custno =pd.concat([df,df1,df2,df3],)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 custno = pd.merge(df,df1,df2,df3, on = "CUSTNO")
#
# TypeError: merge() got multiple values for argument 'on'

# %%
# depart

# %%
# prodclass
